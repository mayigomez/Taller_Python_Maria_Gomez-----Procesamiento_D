# %% [markdown]
# <h2> Bono - Taller Python </h2>

# %% [markdown]
# - Autor: María Clara Gómez Romero.
# - ID: 00020552415
# - Tema: Bono.
# - Descripción: El contenido del siguiente cuarderno es el desarrollo un bono de ejercicios propuestos por el docente, los cuáles son de calentamiento, de nivel 1 y nivel 2.

# %% [markdown]
# ## CALENTAMIENTO:

# %% [markdown]
# #### MENOR DE DOS PARES: Escriba una función que devuelva el menor de dos números dados *si* ambos números son pares, pero devuelva el mayor si uno o ambos números son impares
#     lesser_of_two_evens(2,4) --> 2
#     lesser_of_two_evens(2,5) --> 5

# %%
def lesser_of_two_evens(a,b):
    pass
# Se evalúa si ambos números son pares utilizando el operador módulo (%).
#  Si ambos números son pares, se compara cuál de los dos es menor y se devuelve ese número. 
# Si no ambos números no son pares, se compara cuál de los dos es mayor y se devuelve ese número.
    if (a % 2 == 0 and b % 2 == 0):
        if (a < b):
            return a
        else:
            return b
    else:
        if (a > b):
            return a
        else:
            return b

# %%
# Revisión
lesser_of_two_evens(2,4)
# Out:
# 2

# %%
# Revisión
lesser_of_two_evens(2,5)
# Out:
# 5

# %% [markdown]
# #### GALLETAS DE ANIMALES: Escribir una función que toma una cadena de dos palabras y devuelve True si ambas palabras comienzan con la misma letra
#     animal_crackers('Ciudad Calor') --> True
#     animal_crackers('Lugar Frio') --> False

# %%
def animal_crackers(text):
  pass
  for i in range(len(text)):
    if (text[i] == " "):
       if (text[0] == text[i+1]):
         return True
       else:
         return False

# %%
# Revisión
animal_crackers('Ciudad Calor')
# Out:
# True

# %%
# Revisión
animal_crackers('Lugar Frio')
# Out:
# False

# %% [markdown]
# #### HACE VEINTE: dados dos enteros, devuelve True si la suma de los enteros es 20 o si uno de los enteros es 20. De lo contrario, devuelve False
#
#     makes_twenty(20,10) --> True
#     makes_twenty(12,8) --> True
#     makes_twenty(2,3) --> False

# %%
def makes_twenty(n1,n2):
  pass
  if (n1 + n2 == 20 or n1 == 20 or n2 == 20):
    return True
  else:
    return False

# %%
# Revisión
makes_twenty(20,10)
# Out:
# True

# %%
# Revisión
makes_twenty(2,3)
# Out:
# False

# %%
makes_twenty(12,8)
# Out:
# True

# %% [markdown]
# # Nivel 1

# %% [markdown]
# #### MAYÚSCULAS: Escribir una función que haga mayúscula la primera y cuarta letra de una cadena de texto
#
#     old_macdonald('macdonald') --> MacDonald
#
# Note: `'macdonald'.capitalize()` returns `'Macdonald'`

# %%
def old_macdonald(name):
    pass
    i = 0
    for i in range(len(name)):
        if (i == 0 or i == 3):
            print(name[i].upper(), end="")
            
        else:
            print(name[i], end="")

# %%
# Check
old_macdonald('macdonald')
# Out:
# MacDonald

# %% [markdown]
# #### REVERSA: Dada una oración, retornar la misma oración pero en reversa
#
#     master_yoda('I am home') --> 'home am I'
#     master_yoda('We are ready') --> 'ready are We'
#
# Note: Revisar método .join()
#
#     >>> "--".join(['a','b','c'])
#     >>> 'a--b--c'
#
# Resultado de .join():
#
#     >>> " ".join(['Hello','world'])
#     >>> "Hello world"

# %%
def master_yoda(text):
    pass
#Se crea un bucle for que itere el texto dado desde el último elemento (len(text)-1) 
# hasta el primer elemento (0) con un paso de -1
    for i in range(len(text)-1, -1, -1): 
        #Mientras el bucle esté en ejecución se imprimirá el elemento del texto en la posición i, y con end="" 
        # se evita que se imprima un salto de línea después de cada elemento
        print(text[i], end="")

# %%
# Revisión
master_yoda('I am home')
# Out:
# emoh ma I

# %%
# Revisión
master_yoda('We are ready')
# Out:
# ydaer era eW

# %% [markdown]
# # Nivel 2

# %% [markdown]
# #### PROBLEMA 33:
#
# Dada una lista de enteros, retornar True si el arreglo tiene un  3  seguido por un  3 .
#
#     has_33([1, 3, 3]) → True
#     has_33([1, 3, 1, 3]) → False
#     has_33([3, 1, 3]) → False

# %%
def has_33(nums):
    pass
    for i in range(len(nums)):
        if (nums[i] == 3 and nums[i+1] != 3):
            return False 
        elif (nums[i] == 3 and nums[i+1] == 3):            
            return True

# %%
# Revisión
has_33([1, 3, 3])
# Out:
# True

# %%
# Revisión
has_33([1, 3, 1, 3])
# Out:
# False

# %%
# Revisión
has_33([3, 1, 3])
# Out:
# False

# %% [markdown]
# #### REPLICADOR: Dada una cadena, devuelve una cadena donde por cada carácter en el original hay tres caracteres REPETIDOS
#     paper_doll('Hello') --> 'HHHeeellllllooo'
#     paper_doll('Mississippi') --> 'MMMiiissssssiiippppppiii'

# %%
def paper_doll(text):
    pass
    text_new = ""
    for i in range(len(text)):
        text_new = text_new + text[i]*3
    return text_new

# %%
# Check
paper_doll('Hello')
# Out:
# 'HHHeeellllllooo'

# %%
# Check
paper_doll('Mississippi')
# Out:
# 'MMMiiissssssiiissssssiiippppppiii'

# %% [markdown]
# #### BLACKJACK: Dados tres enteros entre 1 y 11, si su suma es menor o igual a 21, devuelve su suma. Si su suma excede 21 *y* hay un once, reduce la suma total en 10. Finalmente, si la suma (incluso después del ajuste) excede 21, devuelve 'BUST'
#     blackjack(5,6,7) --> 18
#     blackjack(9,9,9) --> 'BUST'
#     blackjack(9,9,11) --> 19

# %%
def blackjack(a,b,c):
    pass
    d = a + b + c
    if (d <= 21):
        return d
    elif (d > 21 and (a == 11 or b == 11 or c == 11)):
        d = d - 10
        if (d > 21):
            return "BUST"
        else:
            return d

# %%
# Revisión
blackjack(5,6,7)
# Out:
# 18

# %%
# Revisión
blackjack(9,9,9)

# %%
# Revisión
blackjack(9,9,11)
# Out:
# 19

# %% [markdown]
# ## Suerte!
