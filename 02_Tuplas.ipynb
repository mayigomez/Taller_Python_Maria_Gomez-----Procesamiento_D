# %% [markdown]
# <h2> Tuplas - Taller de Python </h2>

# %% [markdown]
# - Autor: María Clara Gómez Romero.
# - ID: 00020552415
# - Tema: Tuplas.
# - Descripción: El siguiente cuaderno contiene el desarrollo de algunos ejercicios sobre tuplas, así como, una introducción del tema sobre que son, su funcionamiento y su funcionalidad; asimismo, cuenta con su respectiva conclusión del cuaderno al final del este.

# %% [markdown]
# <h3>Introducción </h3>

# %% [markdown]
#  <div style="text-align: justify;">Las tuplas son estructuras de datos que permiten almacenar varios elementos en una sola variable, de forma ordenada y  que una vez creada una tupla, su contenido no puede ser modificado. En Python, las tuplas se utilizan cuando se requiere asegurar que los valores almacenados no cambien durante la ejecución del programa.
#  En este cuaderno se estudia la sintaxis de las tuplas, el acceso a sus elementos mediante índices y sus principales características en comparación con otras estructuras. </div>

# %% [markdown]
# <h4> Solución del Examen sobre Tuplas </h4>

# %% [markdown]
# Considérese la siguiente tupla:

# %%
# Tupla de ejemplo

genres_tuple = ("pop", "rock", "soul", "hard rock", "soft rock", \
                "R&B", "progressive rock", "disco") #Se guarda una tupla con diferentes palabras (géneros de música)
                                                    # en la variable genres_tuple
genres_tuple
# Out:
# ('pop',
#  'rock',
#  'soul',
#  'hard rock',
#  'soft rock',
#  'R&B',
#  'progressive rock',
#  'disco')

# %% [markdown]
# Encontrar la longitud de la tupla, <code>genres_tuple</code>:

# %%
len(genres_tuple) #Se busca saber cual es la longitud de la tupla previamnete guardada en genres_tuple
# Out:
# 8

# %% [markdown]
# Accede al elemento en el índice 3:

# %%
genres_tuple[3] #Se busca el elemento de la tupla ubicado en índice 3
# Out:
# 'hard rock'

# %% [markdown]
# Utiliza el slicing para obtener los índices 3, 4 y 5:

# %%
genres_tuple[3:6] #Se busca saber cuáles son los géneros musicales que se encuentran entre los índices 3-5
# Out:
# ('hard rock', 'soft rock', 'R&B')

# %% [markdown]
# Encuentra los primeros dos elementos de la tupla <code>genres_tuple</code>:

# %%
genres_tuple[0:2] #Con esto se pretende encontrar cuáles son los dos primeros géneros ubicados en la tupla
# Out:
# ('pop', 'rock')

# %% [markdown]
# Encuentra el primer índice de <code>"disco"</code>:

# %%
genres_tuple.index("disco") #Se busca el índice del elemento "disco" dentro de la tupla
# Out:
# 7

# %% [markdown]
# Genera una lista ordenada desde la tupla <code>C_tuple=(-5, 1, -3)</code>:

# %%
C_tuple = (-5, 1, -3) #Se crea una nueva tupla 'C_tuple' que gusarde los elementos -5, 1 y -3
C_tuple_sorted = sorted(C_tuple)  #Luego, se quiere ordenar los valores que contiene dicha tupla
C_tuple_sorted #Tupla que contiene los elementos ordenados de C_tuple
# Out:
# [-5, -3, 1]

# %% [markdown]
# <h3>Conclusión </h3>

# %% [markdown]
#  <div style="text-align: justify;"> Durante el desarrollo de este cuaderno se pudo comprender el funcionamiento de las tuplas y su principal característica de inmutabilidad. Se aprendió a acceder a sus elementos y a utilizarlas correctamente dentro de un programa (Python). Lo que fue de mucha ayuda al ayuda a reforzar el uso adecuado de estructuras de datos según el tipo de información que se desea manejar.</div>
